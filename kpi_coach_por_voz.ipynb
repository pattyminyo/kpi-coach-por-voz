# %% [markdown]
# <a href="https://colab.research.google.com/github/pattyminyo/kpi-coach-por-voz/blob/main/kpi_coach_por_voz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("KPI Coach por Voz iniciado!")

pergunta = input("Digite sua pergunta comercial: ")

print("Sua pergunta foi:")
print(pergunta)

print("Resposta simulada:")
print("Para melhorar resultados comerciais, acompanhe conversão, churn, CAC e ticket médio.")
# Out:
# KPI Coach por Voz iniciado!
# Digite sua pergunta comercial: Como melhorar vendas?
# Sua pergunta foi:
# Como melhorar vendas?
# Resposta simulada:
# Para melhorar resultados comerciais, acompanhe conversão, churn, CAC e ticket médio.
